# %% [markdown]
# ## Matplotlib for numpy array

# %%
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
x_cor = np.array([0,10])
y_cor = np.array([10,20])

# %%
plt.plot(x_cor,y_cor)
plt.show()
